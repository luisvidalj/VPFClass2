# %% [markdown]
# # Cuaderno para hacer cosas en sucio y demas

# %%
from pathlib import Path
import sys

# root_path = Path.cwd().parents[0]  # Ajusta si estás en /notebooks
# if str(root_path) not in sys.path:
#     sys.path.append(str(root_path))

# %%
src_path = Path("../src").resolve()
if str(src_path) not in sys.path:
    sys.path.append(str(src_path))

sys.path
# Out:
# ['/home/uib/miniconda3/envs/vpf_env/lib/python310.zip',
#  '/home/uib/miniconda3/envs/vpf_env/lib/python3.10',
#  '/home/uib/miniconda3/envs/vpf_env/lib/python3.10/lib-dynload',
#  '',
#  '/home/uib/miniconda3/envs/vpf_env/lib/python3.10/site-packages',
#  '/home/uib/proyectos/VPFTaxoClass/src']

# %%
from Bio import SearchIO
import json
from pathlib import Path
from vpf_classifier.utils.config import Files
# Out:
# ---------------------------------------------------------------------------
# ModuleNotFoundError                       Traceback (most recent call last)
# Cell In[3], line 4
#       2 import json
#       3 from pathlib import Path
# ----> 4 from vpf_classifier.utils.config import Files
#
# ModuleNotFoundError: No module named 'vpf_classifier'
